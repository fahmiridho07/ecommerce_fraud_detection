# %% [markdown]
# # Kaggle Runner
#
# Attach the IEEE-CIS Fraud Detection dataset to this notebook. Project scripts can be run from Kaggle cells with `!python src/script_name.py`.

# %%
from pathlib import Path

kaggle_data_dir = Path('/kaggle/input/ieee-fraud-detection')
print('Kaggle data directory exists:', kaggle_data_dir.exists())

# %% [markdown]
# Later phases can be run here, for example:
#
# ```bash
# !python src/train_baseline_lgbm.py
# ```
